# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mpl_dates

from datetime import datetime

from warnings import filterwarnings
filterwarnings('ignore')

# %%
dates = [
    datetime(2023,10,1),
    datetime(2023,10,2),
    datetime(2023,10,3),
    datetime(2023,10,4),
    datetime(2023,10,5),
    datetime(2023,10,6),
    datetime(2023,10,7)
]

# %%
dates
# Out:
# [datetime.datetime(2023, 10, 1, 0, 0),
#  datetime.datetime(2023, 10, 2, 0, 0),
#  datetime.datetime(2023, 10, 3, 0, 0),
#  datetime.datetime(2023, 10, 4, 0, 0),
#  datetime.datetime(2023, 10, 5, 0, 0),
#  datetime.datetime(2023, 10, 6, 0, 0),
#  datetime.datetime(2023, 10, 7, 0, 0)]

# %%
y = [0,1,3,5,4,6,8]

# %%
plt.plot_date(dates,y,linestyle='solid')

plt.tight_layout()
plt.show()

# %% [markdown]
# gcf().autofmt_xdate()

# %%
plt.plot_date(dates,y,linestyle='solid')
plt.gcf().autofmt_xdate() # Tilt the date vertically

plt.tight_layout()
plt.show()

# %%
plt.plot_date(dates,y,linestyle='solid')
plt.gcf().autofmt_xdate() # Tilt the date vertically

date_format = mpl_dates.DateFormatter('%b,%d %Y')
plt.gca().xaxis.set_major_formatter(date_format)

plt.tight_layout()
plt.show()

# %% [markdown]
# csv data

# %%
df = pd.read_csv('data_ts.csv')
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   18-05-2023  7266.080078  8281.660156  7257.259766  8193.139648
# 1   19-05-2023  8193.139648  8193.139648  7591.850098  7998.290039
# 2   20-05-2023  7998.290039  8102.319824  7807.770020  7947.930176
# 3   21-05-2023  7947.930176  8033.759766  7533.660156  7626.890137
# 4   22-05-2023  7626.890137  7971.259766  7478.740234  7876.500000
# 5   23-05-2023  7876.500000  8165.450195  7801.569824  7996.399902
# 6   24-05-2023  7996.399902  8140.819824  7948.680176  8059.129883
# 7   25-05-2023  8059.129883  8779.000000  7894.529785  8726.230469
# 8   26-05-2023  8726.230469  8931.530273  8668.459961  8785.169922
# 9   27-05-2023  8785.169922  8818.709961  8562.200195  8718.849609
# 10  28-05-2023  8718.849609  8760.480469  8444.099609  8664.559570
# 11  29-05-2023  8664.559570  9065.889648  8027.209961  8276.250000
# 12  30-05-2023  8276.250000  8570.780273  8116.000000  8560.080078
# ...

# %%
price_date = df['Date']
price_close = df['Close']

# %%
plt.figure(figsize=(10,5))
plt.plot_date(price_date,price_close,linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.show()

# %% [markdown]
# but the dates in x-axis are plotted as strings

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       14 non-null     object
#  1   Open       14 non-null     float64
#  2   High       14 non-null     float64
#  3   Low        14 non-null     float64
#  4   Close      14 non-null     float64
#  5   Adj Close  14 non-null     float64
#  6   Volume     14 non-null     int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 916.0+ bytes

# %% [markdown]
# Let's confrim that by manipulating the last date and vizing it again

# %%
# changing the last record of date to one before the start date (or) first record
df.iloc[-1,0]='2023-05-17'

# %%
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   18-05-2023  7266.080078  8281.660156  7257.259766  8193.139648
# 1   19-05-2023  8193.139648  8193.139648  7591.850098  7998.290039
# 2   20-05-2023  7998.290039  8102.319824  7807.770020  7947.930176
# 3   21-05-2023  7947.930176  8033.759766  7533.660156  7626.890137
# 4   22-05-2023  7626.890137  7971.259766  7478.740234  7876.500000
# 5   23-05-2023  7876.500000  8165.450195  7801.569824  7996.399902
# 6   24-05-2023  7996.399902  8140.819824  7948.680176  8059.129883
# 7   25-05-2023  8059.129883  8779.000000  7894.529785  8726.230469
# 8   26-05-2023  8726.230469  8931.530273  8668.459961  8785.169922
# 9   27-05-2023  8785.169922  8818.709961  8562.200195  8718.849609
# 10  28-05-2023  8718.849609  8760.480469  8444.099609  8664.559570
# 11  29-05-2023  8664.559570  9065.889648  8027.209961  8276.250000
# 12  30-05-2023  8276.250000  8570.780273  8116.000000  8560.080078
# ...

# %%
# Plotting the graph again
plt.figure(figsize=(10,5))
plt.plot_date(price_date,price_close,linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.show()

# %% [markdown]
# In the above graph we can see 17th May appears after 30th May which is incorrect. To solve this we have to convert the date column's data type to datetime

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date',inplace=True)

# overwrite the variable
price_date = df['Date'] 
price_close = df['Close']

plt.figure(figsize=(20,5))
plt.plot_date(price_date,price_close,linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.show()
