# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Compute minimum and maximum sales for each store and location
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
df = pd.read_csv('store_sales.csv')
df
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
print('Minimum Sales')
pd.DataFrame(df.groupby(by=['Store','Location'])['Sales'].min())
# Out:
# Minimum Sales
#                  Sales
# Store Location
# A     Delhi      87000
#       Hyderabad  50000
#       Mumbai     40000
#       Pune       78000
# B     Pune       45000
# C     Mumbai     89000
# D     Hyderabad  85000
#       Pune       89000

# %%
print('Maximum Sales')
pd.DataFrame(df.groupby(by=['Store','Location'])['Sales'].max())
# Out:
# Maximum Sales
#                  Sales
# Store Location
# A     Delhi      87000
#       Hyderabad  50000
#       Mumbai     40000
#       Pune       78000
# B     Pune       70000
# C     Mumbai     90000
# D     Hyderabad  85000
#       Pune       89000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Find duplicate rows based on the column 'Name'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachin</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
df1 = pd.DataFrame({'Name':['John','Robert','Aadi','Robert','Robert','Robert','Aadi','Sachine'],'Salary':[3400,3000,1600,3000,3000,3000,4000,3000],
             'City':['Sydney','Chicago','New York','Chicago','Chicago','Texas','London','Chicago']})
df1
# Out:
#       Name  Salary      City
# 0     John    3400    Sydney
# 1   Robert    3000   Chicago
# 2     Aadi    1600  New York
# 3   Robert    3000   Chicago
# 4   Robert    3000   Chicago
# 5   Robert    3000     Texas
# 6     Aadi    4000    London
# 7  Sachine    3000   Chicago

# %%
df1[df1['Name'].duplicated(keep=False)]
# Out:
#      Name  Salary      City
# 1  Robert    3000   Chicago
# 2    Aadi    1600  New York
# 3  Robert    3000   Chicago
# 4  Robert    3000   Chicago
# 5  Robert    3000     Texas
# 6    Aadi    4000    London

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3.  In column tournament, replace all the 'football' values  with 'cricket' using numpy.where
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
df2=pd.DataFrame({'Days':['Mon','Tues','Wed','Thurs','Fri'],'Tournament':['Football','Cricket','Football','Football','Cricket']})
df2
# Out:
#     Days Tournament
# 0    Mon   Football
# 1   Tues    Cricket
# 2    Wed   Football
# 3  Thurs   Football
# 4    Fri    Cricket

# %%
df2['Tournament'] = df2['Tournament'].apply(lambda x:np.where(x=='Football','Cricket',x))

# %%
df2
# Out:
#     Days Tournament
# 0    Mon    Cricket
# 1   Tues    Cricket
# 2    Wed    Cricket
# 3  Thurs    Cricket
# 4    Fri    Cricket

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Get the descriptive statistics of the sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
df3=pd.DataFrame({'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],
           'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],
          'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']})
df3
# Out:
#    Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8    Sep  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter

# %%
df3.groupby(by='Seasons')['Sales'].describe()
# Out:
#          count          mean           std      min      25%      50%  \
# Seasons
# Fall       3.0  56000.000000      0.000000  56000.0  56000.0  56000.0
# Spring     3.0  29666.666667   5033.222957  25000.0  27000.0  29000.0
# Summer     3.0  70666.666667   6350.852961  67000.0  67000.0  67000.0
# Winter     3.0  36333.333333  20647.840888  22000.0  24500.0  27000.0
#
#              75%      max
# Seasons
# Fall     56000.0  56000.0
# Spring   32000.0  35000.0
# Summer   72500.0  78000.0
# Winter   43500.0  60000.0

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Create a new column age with values of your choice. And append it to the below dataframe.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
df4=pd.DataFrame({'Name':['Emma','Mia','Sophia','James','John'],'Maths':[56,78,78,67,88],
                  'Science':[89,87,78,89,78],'English':[89,89,76,78,87]})
df4
# Out:
#      Name  Maths  Science  English
# 0    Emma     56       89       89
# 1     Mia     78       87       89
# 2  Sophia     78       78       76
# 3   James     67       89       78
# 4    John     88       78       87

# %%
df4['Age'] = [15,14,15,13,16]
df4
# Out:
#      Name  Maths  Science  English  Age
# 0    Emma     56       89       89   15
# 1     Mia     78       87       89   14
# 2  Sophia     78       78       76   15
# 3   James     67       89       78   13
# 4    John     88       78       87   16

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Perform right join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#         <td>Geography</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#         <td>History</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
df5_1=pd.DataFrame({'Stud_Id':[101,102,103,104,105],
                    'Name':['Alex','Amy','Allen','Alice','James'],
                    'MA(Hons)':['History','English','Geography','German','History']})

df5_2=pd.DataFrame({'Stud_Id':[101,102,103,104,105],'Res_City':['Delhi','Mumbai','Delhi','Chennai','Hyderabad'],
                    'MA(Hons)':['History','English','Geography','German','History']})

# %%
df5_1
# Out:
#    Stud_Id   Name   MA(Hons)
# 0      101   Alex    History
# 1      102    Amy    English
# 2      103  Allen  Geography
# 3      104  Alice     German
# 4      105  James    History

# %%
df5_2
# Out:
#    Stud_Id   Res_City   MA(Hons)
# 0      101      Delhi    History
# 1      102     Mumbai    English
# 2      103      Delhi  Geography
# 3      104    Chennai     German
# 4      105  Hyderabad    History

# %%
pd.merge(df5_1,df5_2,on=['MA(Hons)','Stud_Id'],how='left')
# Out:
#    Stud_Id   Name   MA(Hons)   Res_City
# 0      101   Alex    History      Delhi
# 1      102    Amy    English     Mumbai
# 2      103  Allen  Geography      Delhi
# 3      104  Alice     German    Chennai
# 4      105  James    History  Hyderabad

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Using the dataframes created in question 6, perform inner join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.merge(df5_1,df5_2,on=['MA(Hons)','Stud_Id'],how='inner')
# Out:
#    Stud_Id   Name   MA(Hons)   Res_City
# 0      101   Alex    History      Delhi
# 1      102    Amy    English     Mumbai
# 2      103  Allen  Geography      Delhi
# 3      104  Alice     German    Chennai
# 4      105  James    History  Hyderabad

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8. Concatenate two dataframes along the columns
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
df6_1=pd.DataFrame({'Stud_Id':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','James']})
df6_2=pd.DataFrame({'Res_City':['Delhi','Mumbai','Delhi','Chennai','Hyderabad'],'MA(Hons)':['History','English','Geography','German','History']})

# %%
df6_1
# Out:
#    Stud_Id   Name
# 0      101   Alex
# 1      102    Amy
# 2      103  Allen
# 3      104  Alice
# 4      105  James

# %%
df6_2
# Out:
#     Res_City   MA(Hons)
# 0      Delhi    History
# 1     Mumbai    English
# 2      Delhi  Geography
# 3    Chennai     German
# 4  Hyderabad    History

# %%
pd.concat([df6_1,df6_2],axis=1,join='outer')
# Out:
#    Stud_Id   Name   Res_City   MA(Hons)
# 0      101   Alex      Delhi    History
# 1      102    Amy     Mumbai    English
# 2      103  Allen      Delhi  Geography
# 3      104  Alice    Chennai     German
# 4      105  James  Hyderabad    History

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9. Calculate minimum, maximum and average sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df3
# Out:
#    Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8    Sep  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter

# %%
print('Minimum Sales in each Season')
print(df3.groupby(by='Seasons')['Sales'].min())
print()
print('Maximum Sales in each season')
print(df3.groupby(by='Seasons')['Sales'].max())
print()
print('Average sales for each season')
print(df3.groupby(by='Seasons')['Sales'].mean())
# Out:
# Minimum Sales in each Season
# Seasons
# Fall      56000
# Spring    25000
# Summer    67000
# Winter    22000
# Name: Sales, dtype: int64
#
# Maximum Sales in each season
# Seasons
# Fall      56000
# Spring    35000
# Summer    78000
# Winter    60000
# Name: Sales, dtype: int64
#
# Average sales for each season
# Seasons
# Fall      56000.000000
# Spring    29666.666667
# Summer    70666.666667
# Winter    36333.333333
# Name: Sales, dtype: float64

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10. Find all the duplicate entries based on the columns X and Y.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>X</th>
# <th>Y</th>
# <th>Z</th>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>5</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>3</td>
# <td>1</td>
# <td>2</td>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>1</td>
# </tr>
# <tr>
# <td>3</td>
# <td>4</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>2</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>8</td>
# </tr>
#
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
df7=pd.DataFrame({'X':[1,2,3,1,2,3,2,2],'Y':[2,2,1,2,2,4,2,2],'Z':[5,6,2,6,1,6,2,8]})
df7[df7.duplicated(subset=['X','Y'],keep=False)]
# Out:
#    X  Y  Z
# 0  1  2  5
# 1  2  2  6
# 3  1  2  6
# 4  2  2  1
# 6  2  2  2
# 7  2  2  8

# %%
df7[df7[['X','Y']].duplicated(keep=False)]
# Out:
#    X  Y  Z
# 0  1  2  5
# 1  2  2  6
# 3  1  2  6
# 4  2  2  1
# 6  2  2  2
# 7  2  2  8
